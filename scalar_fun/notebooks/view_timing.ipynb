# %% [markdown]
# # Viewing the Processor Interaction
#
# In this notebook, we will show how to visualize the timing for the interaction between the Vitis IP and processor.  Before running the notebook, you should complete the steps for [running the RTL simulation](https://sdrangan.github.io/hwdesign/scalar_fun/rtlsim.html).  This step will create a [**Value Change Dump**](https://en.wikipedia.org/wiki/Value_change_dump)  or **VCD** file with the values for all the signals between the IP and processor.

# %% [markdown]
# ## Parsing the VCD file
#
#
# First we import the relevant packages.

# %%
from vcdvcd import VCDVCD
import matplotlib.pyplot as plt

# %% [markdown]
# We parse the VCD file using the `VCDVCD` package.  The parsed data is in the `vcd` object.

# %%
# Check if VCD file exists
import os
fn = os.path.join(os.getcwd(), '..', 'scalar_fun_vitis', 'vcd', 'dump.vcd')
if not os.path.exists(fn):
    raise FileNotFoundError(f"VCD file not found: {fn}")

# Parse the VCD file
vcd = VCDVCD(fn, signals=None, store_tvs=True)

# %% [markdown]
# The RTL simulation records traces for a large number of signals.  You can get a full list with the following command.  You will see that there are over 200 such signals.

# %%
nsig = len(vcd.signals)
print(f"Number of signals in VCD: {nsig}")
print(vcd.signals)
# Out:
# Number of signals in VCD: 265
# ['apatb_add_top.AESL_clock', 'apatb_add_top.rst', 'apatb_add_top.dut_rst', 'apatb_add_top.start', 'apatb_add_top.ce', 'apatb_add_top.tb_continue', 'apatb_add_top.AESL_start', 'apatb_add_top.AESL_reset', 'apatb_add_top.AESL_ce', 'apatb_add_top.AESL_ready', 'apatb_add_top.AESL_idle', 'apatb_add_top.AESL_continue', 'apatb_add_top.AESL_done', 'apatb_add_top.AESL_done_delay', 'apatb_add_top.AESL_done_delay2', 'apatb_add_top.AESL_ready_delay', 'apatb_add_top.ready', 'apatb_add_top.ready_wire', 'apatb_add_top.control_AWADDR[5:0]', 'apatb_add_top.control_AWVALID', 'apatb_add_top.control_AWREADY', 'apatb_add_top.control_WVALID', 'apatb_add_top.control_WREADY', 'apatb_add_top.control_WDATA[31:0]', 'apatb_add_top.control_WSTRB[3:0]', 'apatb_add_top.control_ARADDR[5:0]', 'apatb_add_top.control_ARVALID', 'apatb_add_top.control_ARREADY', 'apatb_add_top.control_RVALID', 'apatb_add_top.control_RREADY', 'apatb_add_top.control_RDATA[31:0]', 'apatb_add_top.control_RRESP[1:0]', 'apatb_add_top.control_BVALID', 'apatb_add_top.control_BREADY', 'apatb_add_top.control_BRESP[1:0]', 'apatb_add_top.control_INTERRUPT', 'apatb_add_top.done_cnt[31:0]', 'apatb_add_top.AESL_ready_cnt[31:0]', 'apatb_add_top.ready_cnt[31:0]', 'apatb_add_top.ready_initial', 'apatb_add_top.ready_initial_n', 'apatb_add_top.ready_last_n', 'apatb_add_top.ready_delay_last_n', 'apatb_add_top.done_delay_last_n', 'apatb_add_top.interface_done', 'apatb_add_top.control_read_data_finish', 'apatb_add_top.control_write_data_finish', 'apatb_add_top.AESL_slave_start', 'apatb_add_top.AESL_slave_start_lock', 'apatb_add_top.AESL_slave_write_start_in', 'apatb_add_top.AESL_slave_write_start_finish', 'apatb_add_top.AESL_slave_ready', 'apatb_add_top.AESL_slave_output_done', 'apatb_add_top.AESL_slave_done', 'apatb_add_top.ready_rise', 'apatb_add_top.start_rise', 'apatb_add_top.slave_start_status', 'apatb_add_top.slave_done_status', 'apatb_add_top.ap_done_lock', 'apatb_add_top.all_finish', 'apatb_add_top.ap_clk', 'apatb_add_top.ap_rst_n', 'apatb_add_top.ap_rst_n_n', 'apatb_add_top.clk_cnt[31:0]', 'apatb_add_top.AESL_ready_p1', 'apatb_add_top.AESL_start_p1', 'apatb_add_top.start_cnt[31:0]', 'apatb_add_top.ap_ready_cnt[31:0]', 'apatb_add_top.finish_cnt[31:0]', 'apatb_add_top.lat_total[31:0]', 'apatb_add_top.report_progress', 'apatb_add_top.progress_timeout[31:0]', 'apatb_add_top.AESL_inst_add.ap_clk', 'apatb_add_top.AESL_inst_add.ap_rst_n', 'apatb_add_top.AESL_inst_add.s_axi_control_AWVALID', 'apatb_add_top.AESL_inst_add.s_axi_control_AWREADY', 'apatb_add_top.AESL_inst_add.s_axi_control_AWADDR[5:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_WVALID', 'apatb_add_top.AESL_inst_add.s_axi_control_WREADY', 'apatb_add_top.AESL_inst_add.s_axi_control_WDATA[31:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_WSTRB[3:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_ARVALID', 'apatb_add_top.AESL_inst_add.s_axi_control_ARREADY', 'apatb_add_top.AESL_inst_add.s_axi_control_ARADDR[5:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_RVALID', 'apatb_add_top.AESL_inst_add.s_axi_control_RREADY', 'apatb_add_top.AESL_inst_add.s_axi_control_RDATA[31:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_RRESP[1:0]', 'apatb_add_top.AESL_inst_add.s_axi_control_BVALID', 'apatb_add_top.AESL_inst_add.s_axi_control_BREADY', 'apatb_add_top.AESL_inst_add.s_axi_control_BRESP[1:0]', 'apatb_add_top.AESL_inst_add.interrupt', 'apatb_add_top.AESL_inst_add.ap_rst_n_inv', 'apatb_add_top.AESL_inst_add.ap_start', 'apatb_add_top.AESL_inst_add.ap_done', 'apatb_add_top.AESL_inst_add.ap_idle', 'apatb_add_top.AESL_inst_add.ap_CS_fsm[2:0]', 'apatb_add_top.AESL_inst_add.ap_CS_fsm_state1', 'apatb_add_top.AESL_inst_add.ap_ready', 'apatb_add_top.AESL_inst_add.a[31:0]', 'apatb_add_top.AESL_inst_add.b[31:0]', 'apatb_add_top.AESL_inst_add.c_ap_vld', 'apatb_add_top.AESL_inst_add.b_read_reg_61[31:0]', 'apatb_add_top.AESL_inst_add.a_read_reg_66[31:0]', 'apatb_add_top.AESL_inst_add.add_ln7_fu_57_p2[31:0]', 'apatb_add_top.AESL_inst_add.add_ln7_reg_71[31:0]', 'apatb_add_ ...

# %% [markdown]
# ## Plotting a Timeing Diagram
#
# To visualize the interaction between the processor and IP, it is useful to create a **timing diagram**.  For this purpose, I have created a class, `VCDViewer` in the package `xilinxutils` that is part of the course repository.  We can import the package as follows.

# %%
import importlib

import xilinxutils
importlib.reload(xilinxutils.vcd)
from xilinxutils.vcd import VcdViewer

# %% [markdown]
# The following code:
# * Creates a viewing class
# * Adds the **status signals** such as `start`, `idle` that tell when the IP should execute.
# * Adds the **S-AXI-Lite signals** for the interface for the processor to read and write to the Vitis IP.
# * Creates the timing diagram for the signals.

# %%
# Create a viewing class
vw = VcdViewer(vcd)

# Add status and S-AXI-Lite signals
vw.add_status_signals()
vw.add_saxi_signals()

# Plot the timing diagram
ax = vw.plot_signals(left_border=50)
ax.set_xlabel('Time [ns]')
plt.show()

# %% [markdown]
# We can see the various phases of the **execution model**:
#
# * The testbench first writes the two inputs to the IP:
#     * Write  `WDATA = 7` and `5` to addresses `AWADDR = 16` and `24`
# * Starts execution with `start=1`
# * IP completes execution with strobing `done=1`
# * Testbench reads the result `RDATA=12` from read address `ARADDR = 32`.

# %%
# Out:
# False
